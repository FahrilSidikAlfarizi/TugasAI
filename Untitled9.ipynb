# %%
import pandas as pd
dataset = "/content/data-motor.csv"
df = pd.read_csv(dataset)

df.head(26)
# Out:
#     No     Merek        Model   Tahun  Warna          Harga
# 0    1     Honda         Beat  2021.0  Merah  Rp 15.000.000
# 1    2    Yamaha         NMAX  2022.0  Hitam            NaN
# 2    3    Suzuki  Satria F150  2021.0   Biru  Rp 20.000.000
# 3    4  Kawasaki    Ninja 250  2022.0  Hijau  Rp 40.000.000
# 4    5    Yamaha    Aerox 155     NaN  Merah  Rp 22.000.000
# 5    6     Honda      PCX 150  2021.0  Hitam  Rp 28.000.000
# 6    7    Suzuki  Address 115  2021.0   Biru  Rp 17.000.000
# 7    8  Kawasaki         Z125  2022.0  Hijau  Rp 35.000.000
# 8    9     Honda    Vario 150  2022.0  Merah  Rp 20.000.000
# 9   10    Yamaha       X-Ride  2021.0     54  Rp 18.000.000
# 10  11    Suzuki     GSX-R150  2022.0   Biru  Rp 32.000.000
# 11  12  Kawasaki          NaN  2021.0  Hijau  Rp 19.000.000
# 12  13     Honda      CBR150R  2022.0  Merah  Rp 30.000.000
# 13  14    Yamaha        MT-15  2021.0  Hitam  Rp 24.000.000
# 14  15    Suzuki       Nex II  2021.0   Biru  Rp 15.000.000
# ...

# %%
print(df['Model'].isna().sum())

df['Model'].fillna('N', inplace=True)

print(df['Model'].isna().sum())
# Out:
# 1
# 0

# %%
print(df['Tahun'].isna().sum())

df['Tahun'].fillna('N', inplace=True)

print(df['Tahun'].isna().sum())
# Out:
# 1
# 0

# %%
print(df['Harga'].isna().sum())

df['Harga'].fillna('N', inplace=True)

print(df['Harga'].isna().sum())
# Out:
# 1
# 0

# %%
df['Warna'].replace(['54'], ['Hitam'], inplace=True)

print(df['Warna'].value_counts())
# Out:
# Merah    7
# Hitam    6
# Hijau    6
# Biru     5
# Putih    1
# Name: Warna, dtype: int64
